# %% [markdown]
# <a href="https://colab.research.google.com/github/JiYechan/class2021fall/blob/main/20211122.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
import IPython.display as ipd

# %%
amp=1
sr = 10000
dur = 0.5
freq =100
phase = np.pi/2

# %%
nSamp = sr * dur
samples = np.arange(1, nSamp+1)

# %%
t = samples/sr

# %%
theta0 = t*2*np.pi*freq

# %%
theta = theta0+ phase

# %%
s= amp * np.sin(theta)

# %%
def phasor_sine(amp, sr, dur, freq, phase):
  t = np.arange(1, sr * dur+1)/sr
  theta = t*2*np.pi*freq+phase
  s=amp*np.sin(theta)
  return s, t, theta

# %%
amp = 1; sr = 10000; phase = 0

A4  = 440
C5  = 523.25
D5  = 587.33
E5  = 659.25	 
Eb5 = 622.25 
F5  = 698.46 
G5  = 783.99
D6 = 1174.66

# %%
#Jingle bell

notes = [E5, E5, E5, E5, E5, E5, E5, G5, C5, D5, E5, 0, 
         F5, F5, F5, F5, F5, E5, E5, E5, E5, D5, D5, E5, D5, G5, 
         E5, E5, E5, E5, E5, E5, E5, G5, C5, D5, E5, 0, 
          F5, F5, F5, F5, F5, E5, E5, E5, G5, G5, F5, D5, C5 ,0]

durs = [0.25, 0.25, 0.5, 0.25, 0.25, 0.5, 0.25, 0.25, 0.25, 0.25, 0.75, 0.25, 
        0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.5, 0.5,
        0.25, 0.25, 0.5, 0.25, 0.25, 0.5, 0.25, 0.25, 0.25, 0.25, 0.75, 0.25, 
        0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25, 0.25,0.75,0.25]

# %%
s_all =np.empty(0)

for note, dur in zip(notes, durs):
  s, t, th = phasor_sine(amp, sr, dur, note, phase)
  s_all = np.concatenate((s_all, s))

# %%
ipd.Audio(s_all, rate=sr)
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
